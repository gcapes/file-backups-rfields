# %%
import os

def listFilesAndDirs(path,allFiles):
    for fileOrDir in os.listdir(path):
        if os.path.isdir(fileOrDir):
            listFilesAndDirs(os.path.join(path,fileOrDir),allFiles)
        else:
            allFiles.append(os.path.join(path,fileOrDir))
    return allFiles

for x in listFilesAndDirs('.',[]):
    print(x)
# Out:
# ./OpenVPN  Installation Guide.pdf
# ./matlab-programming-master.zip
# ./ubuntu-16.04.3-desktop-amd64.iso
# ./UoM-vpnc.txt
# ./linuxmint-18.3-cinnamon-64bit.iso
# ./data/inflammation-04.csv
# ./data/inflammation-02.csv
# ./data/inflammation-12.csv
# ./data/inflammation-08.csv
# ./data/inflammation-09.csv
# ./data/inflammation-07.csv
# ./data/inflammation-03.csv
# ./data/inflammation-05.csv
# ./data/small-01.csv
# ./data/.ipynb_checkpoints/scw-nov2017-checkpoint.ipynb
# ./data/inflammation-10.csv
# ./data/small-03.csv
# ./data/inflammation-11.csv
# ./data/small-02.csv
# ./data/inflammation-06.csv
# ./data/inflammation-01.csv
# ./Tracked_Returns_label_VZ008021315GB.pdf
# ./DD122-SIMPLE-User-Manual.pdf
# ./DD122FW-MK5-Classic-Users-Manual.pdf ORIG
# ./MatlabStyle1p5.zip
# ./seven_day_itch.pdf
# ./.ipynb_checkpoints/Untitled-checkpoint.ipynb
# ./.ipynb_checkpoints/scw-nov2017-checkpoint.ipynb
# ./.ipynb_checkpoints/ep4-checkpoint.ipynb
# ./matlab-programming-master/index.html
# ./matlab-programming-master/code
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1983.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1988.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1989.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2004.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1984.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2015.txt
# ./matlab-programming-master/data/co2_weekly_mlo.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1981.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2007.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2013.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2006.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2011.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2016.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1977.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1999.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1994.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1985.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1986.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1990.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1980.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2003.txt
# ./matlab-programming-master/data/co2_data_mlo.png
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1979.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1991.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1987.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2014.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2009.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1992.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2000.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1993.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1995.txt
# ./matlab-programming-master/data/met_README
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2010.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2012.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1996.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1997.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2008.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2005.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2002.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1998.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1978.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_1982.txt
# ./matlab-programming-master/data/met_mlo_insitu_1_obop_hour_2001.txt
# ./matlab-programming-master/guide.md
# ./matlab-programming-master/debug
# ./matlab-programming-master/README.md
# ./testplot.py
# ./ep4.ipynb
# ./ubuntu-16.04.3-desktop-amd64.iso.torrent
# ./linuxmint-18.2-cinnamon-64bit.iso
# ./FAQ-TRVs-explained.pdf
# ./license.txt
# ./remarkable_1.87_all.deb
# ./mandel-cuda.py
# ./opera-stable_49.0.2725.64_amd64.deb
# ./Untitled.ipynb
# ./matlab-guidelines.zip
# ./scw-nov2017.ipynb
# ./Staff Survey - IT Services Directorate level plan V8.pdf
# ./Re_ Alpkit - #6463 - Re_ Thank you for your Alpkit order - gerardcapes@gmail.pdf
# ./toolbox.pdf
# ./python-novice-inflammation-data.zip
# ./license.lic
# ./landesk-tickets.txt
# ./TrainingCatalogueEventBookings.xls
# ./freesurfer-v6.0.0.sh
